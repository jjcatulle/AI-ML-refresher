# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %%
# First run check (beginner safe)
import sys

print('Python version:', sys.version.split()[0])
print('Environment check passed.')
print('Proceed to define agent schemas in the next challenge.')

# %% [markdown]
# # Beginner Start Here (Weeks 11-12: Multi-Agent)
#
# You do not need prior agent-framework experience. This starter introduces the concepts.
#
# ## What is an agent?
# An agent is a system component that receives a task and decides actions.
#
# ## What is a multi-agent system?
# Multiple specialized agents collaborate:
# - Planner: breaks task into steps.
# - Researcher: gathers evidence.
# - Writer: drafts output.
# - Critic: checks correctness and quality.
#
# ## Key terms
# - Orchestration: controlling which agent runs and when.
# - Reflection loop: retrying with feedback when quality is low.
# - Tool call: using external functions/APIs (search, calculator, db).
# - State: shared context passed between agents.
#
# ## How to work through this notebook
# 1. Define clear input/output schema per agent.
# 2. Build one-direction pipeline first.
# 3. Add critic feedback loop second.
# 4. Add evaluation logging last.

# %% [markdown]
# # STARTER: Weeks 11-12 Multi-Agent Orchestration
#
# This starter focuses on planner/researcher/writer/critic architecture with reflection and retries.

# %% [markdown]
# ## Challenge 1: Define Agent Contracts
#
# Create structured input/output schema for each agent.
#
# - Planner: task plan
# - Researcher: evidence collection
# - Writer: draft report
# - Critic: validation report

# %%
# YOUR CODE HERE
# Define dataclasses or pydantic models for each agent I/O

# %% [markdown]
# ## Challenge 2: Build Plan-and-Execute Flow
#
# Run planner -> researcher -> writer and return final draft with trace logs.

# %%
# YOUR CODE HERE
# Implement orchestration function with explicit handoff state

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before agent experimentation and model/system comparisons.
#
# Use Phase 0 as your reference for workflow discipline:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 2 sections)
#
# Questions to answer in markdown before moving on:
# 1. What data or tool-input quality issues could break the agent flow?
# 2. What transformations or validation are needed before running tools?
# 3. What baseline behavior will you compare against?
# 4. Which failure modes should be tracked from day one?
#
# Done criteria:
# - You can explain preparation and validation before running the agent.
# - You have a baseline and failure-tracking plan.
# - You are ready for controlled iteration.

# %% [markdown]
# ## Challenge 3: Add Critic + Reflection
#
# If critic score is below threshold, trigger targeted rewrite loop.

# %%
# YOUR CODE HERE
# Add critic checks and retry policy

# %% [markdown]
# ## Challenge 4: Evaluation Harness
#
# Create a small eval dataset and score outcomes per agent and end-to-end.

# %%
# YOUR CODE HERE
# Log pass/fail and score trends

# %% [markdown]
# ## Tuning Learning Checkpoint
#
# ### What tuning means in this project
# For an agent system, tuning means adjusting the system rules and components that affect task success, safety, and latency.
#
# ### What you should tune first
# - Start with a baseline workflow and a small eval set.
# - Tune tool-selection rules, retries, timeouts, retrieval settings, and prompt instructions one at a time.
# - Keep model choice fixed at first unless there is a strong reason to change it.
#
# ### What to watch for
# - Better task success can come with worse latency or cost.
# - More tool calls can improve coverage but also create error chains.
#
# ### Questions to answer in this notebook
# 1. What agent behavior failed most often?
# 2. Which setting did I tune to address that failure?
# 3. Did task success improve without hurting latency or reliability too much?
# 4. What safety or failure mode still remains?
#
# See also: `docs/HYPERPARAMETER_TUNING_GUIDE.md` and `docs/EVALUATION_FRAMEWORK.md`.

# %% [markdown]
# ## Tuning Report Template
#
# Use this version for agent systems.
#
# ```text
# Tuning target: improve full-agent behavior
# Baseline system:
# Baseline success / latency / cost / reliability:
#
# Failure mode I was trying to improve:
# - poor task success
# - too many retries or tool failures
# - latency too high
# - quality improved but cost too high
#
# Setting(s) tuned:
# - prompt structure
# - tool rules
# - retries / timeouts
# - retrieval settings
# - model choice or guardrail thresholds
#
# Why I chose these first:
#
# Validation method used:
# Metric optimized:
#
# Best setting found:
# Best validation result:
#
# What improved:
# What got worse:
# Production tradeoff accepted:
#
# Final test result:
# Next tuning step:
# ```

# %%
# Tuning evidence log template
import pandas as pd

tuning_runs = [
    {
        'run_name': 'baseline',
        'setting_changed': 'none',
        'metric_optimized': 'task_success',
        'validation_score': None,
        'test_score': None,
        'notes': 'starting agent workflow',
    },
    {
        'run_name': 'trial_1',
        'setting_changed': 'retry_policy=2, timeout=15',
        'metric_optimized': 'reliability',
        'validation_score': None,
        'test_score': None,
        'notes': 'track latency and cost too',
    },
]

tuning_log_df = pd.DataFrame(tuning_runs)
tuning_log_df

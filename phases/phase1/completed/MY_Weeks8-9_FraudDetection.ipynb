# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %%
# First run check (beginner safe)
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print('Python version:', sys.version.split()[0])
print('NumPy version:', np.__version__)
print('pandas version:', pd.__version__)
print('Setup check passed. You can continue.')

# %% [markdown]
# # Weeks 8-9: Fraud Detection Risk Scorer
#
# ## Beginner Start Here
# Fraud detection is an imbalanced classification problem.
#
# ### Key terms
# - Class imbalance: fraud is rare compared to non-fraud.
# - Precision: among predicted fraud, how many are truly fraud.
# - Recall: among true fraud, how many you catch.
# - PR-AUC: preferred summary metric for imbalanced binary classification.
# - Threshold: probability cutoff used to label fraud.
#
# ### Notebook workflow
# 1. Load and inspect data.
# 2. Build baseline model.
# 3. Evaluate with precision/recall/PR-AUC.
# 4. Tune threshold.
# 5. Build risk-scoring function and summary.

# %% [markdown]
# ## Imports and Helpers

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, HistGradientBoostingClassifier
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    confusion_matrix, classification_report,
    precision_recall_curve, average_precision_score,
    roc_auc_score
)
from sklearn.calibration import CalibratedClassifierCV

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ## Challenge 1: Load and Profile Class Imbalance
#
# Goal: Load fraud dataset and inspect target imbalance.
#
# Tasks:
# - Load CSV (or create fallback synthetic data if file missing).
# - Print shape, columns, dtypes.
# - Print fraud rate and class counts.

# %%
# Challenge 1: YOUR CODE HERE

# %% [markdown]
# ## Challenge 2: Leakage Checks and Proper Splits
#
# Goal: Build train/validation/test splits with stratification and remove leak-prone columns.
#
# Tasks:
# - Identify columns that leak target information (if any).
# - Split X/y into train, validation, and test using stratify.
# - Confirm class ratios are similar across splits.

# %%
# Challenge 2: YOUR CODE HERE

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before starting visualization and model training.
#
# Use Phase 0 as your reference:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 1 sections)
#
# Questions to answer in markdown before moving on:
# 1. What data quality issues exist (missing values, wrong types, duplicates, outliers)?
# 2. What needs to be transformed before training, and why?
# 3. Is the target variable clearly defined and consistently encoded?
# 4. What preprocessing choices could change model behavior?
# 5. What baseline will you compare against after training?
#
# Done criteria:
# - You can explain your data fixing and preparation plan in plain language.
# - You can justify preprocessing decisions before training begins.
# - You are ready to continue with a clean data strategy.

# %% [markdown]
# ## Challenge 3: Baseline Model and Naive Threshold
#
# Goal: Train a baseline logistic model and evaluate with threshold 0.5.
#
# Tasks:
# - Build preprocessing for numeric + categorical columns.
# - Train LogisticRegression(class_weight='balanced').
# - Generate validation probabilities and labels at threshold 0.5.

# %%
# Challenge 3: YOUR CODE HERE

# %% [markdown]
# ## Challenge 4: Core Metrics (Precision, Recall, F1, ROC-AUC, PR-AUC)
#
# Goal: Report fraud-relevant metrics and explain trade-offs.

# %%
# Challenge 4: YOUR CODE HERE

# %% [markdown]
# ## Challenge 5: Threshold Sweep and Cost-Aware Operating Point
#
# Goal: Sweep thresholds and pick one using business constraints.
#
# Tasks:
# - Evaluate thresholds from 0.05 to 0.95.
# - Track precision, recall, and F1.
# - Choose threshold maximizing precision with recall >= target (for example 0.80).

# %%
# Challenge 5: YOUR CODE HERE

# %% [markdown]
# ## Challenge 6: Confusion Matrix by Threshold
#
# Goal: Compare confusion matrices at two thresholds and explain business impact.

# %%
# Challenge 6: YOUR CODE HERE

# %% [markdown]
# ## Challenge 7: Class-Weight vs Alternative Model
#
# Goal: Compare at least two modeling strategies under imbalance.
#
# Ideas:
# - LogisticRegression(class_weight='balanced')
# - RandomForestClassifier(class_weight='balanced')
# - HistGradientBoostingClassifier with tuned hyperparameters

# %%
# Challenge 7: YOUR CODE HERE

# %% [markdown]
# ## Challenge 8: Feature Importance and Error Slices
#
# Goal: Inspect what drives fraud predictions and where the model fails most.

# %%
# Challenge 8: YOUR CODE HERE

# %% [markdown]
# ## Challenge 9: Calibration and Reliability Curve
#
# Goal: Calibrate probabilities and assess reliability.

# %%
# Challenge 9: YOUR CODE HERE

# %% [markdown]
# ## Challenge 10: Top-Risk Ranking (Precision@k)
#
# Goal: Evaluate analyst review quality using precision@k.
#
# Tasks:
# - Rank validation transactions by predicted probability.
# - Compute precision@100 and precision@500 (or realistic review budget).

# %%
# Challenge 10: YOUR CODE HERE

# %% [markdown]
# ## Challenge 11: Build Risk Scoring Inference Function
#
# Goal: Wrap the best model into a reusable scoring function that returns:
# - fraud_probability
# - fraud_flag
# - threshold_used

# %%
# Challenge 11: YOUR CODE HERE

# %% [markdown]
# ## Challenge 12: Fraud Operations Summary
#
# Goal: Write a plain-language summary for stakeholders.
#
# Include:
# - final model and why
# - chosen threshold and trade-off
# - expected review volume
# - key risks and next improvements

# %%
# Challenge 12: YOUR CODE HERE

# %% [markdown]
# ## Reflection Questions
#
# 1. Why can a model with very high accuracy still be bad for fraud detection?
# 2. Which threshold did you choose, and what did you optimize for?
# 3. What metric is most useful when fraud analysts can only review top-k transactions?
# 4. Did calibration improve decision quality? How?
# 5. What is your next model or data improvement?

# %% [markdown]
# ## Checklist
#
# - [ ] I used stratified train/validation/test splits
# - [ ] I trained a baseline model
# - [ ] I reported precision, recall, F1, PR-AUC
# - [ ] I performed threshold sweep
# - [ ] I compared at least two model strategies
# - [ ] I reviewed confusion matrix trade-offs
# - [ ] I computed precision@k
# - [ ] I built a risk scoring function

# %% [markdown]
# ## Tuning Learning Checkpoint
#
# ### What tuning means in this project
# In fraud detection, tuning is not just about the model. It also includes threshold tuning, class weighting, and making sure the metric matches the imbalance problem.
#
# ### What you should tune first
# - Start with a baseline and inspect the confusion matrix.
# - Tune the **decision threshold** first when recall is too low or false alarms are too high.
# - Tune `class_weight`, `max_depth`, `learning_rate`, or `n_estimators` after that.
#
# ### What not to optimize blindly
# - Accuracy is usually misleading on fraud data.
# - A better ROC-AUC does not automatically mean the thresholded business outcome is better.
#
# ### Questions to answer in this notebook
# 1. What minority-class metric am I optimizing?
# 2. Did threshold tuning help before model tuning?
# 3. Which fraud cases are still missed after tuning?
# 4. What extra cost comes from the new false positives?
#
# See also: `docs/HYPERPARAMETER_TUNING_GUIDE.md` and `docs/QUICK_REFERENCE.md`.

# %% [markdown]
# ## Tuning Report Template
#
# Use this version for fraud or other imbalanced classification work.
#
# ```text
# Tuning target: improve minority-class detection
# Baseline model:
# Baseline precision / recall / PR-AUC / F1:
#
# Failure mode I was trying to improve:
# - too many missed fraud cases
# - too many false alerts
# - weak performance at the operating threshold
#
# Setting(s) tuned:
# - threshold
# - class_weight
# - sampling strategy
# - max_depth / learning_rate / n_estimators
#
# Why I chose these first:
#
# Validation method used:
# Metric optimized:
#
# Best setting found:
# Best validation result:
#
# What improved:
# What got worse:
# Operational cost of new false positives:
#
# Final test result:
# Tradeoff accepted:
# Next tuning step:
# ```

# %%
# Tuning evidence log template
import pandas as pd

tuning_runs = [
    {
        'run_name': 'baseline',
        'setting_changed': 'none',
        'metric_optimized': 'pr_auc',
        'validation_score': None,
        'test_score': None,
        'notes': 'starting point',
    },
    {
        'run_name': 'trial_1',
        'setting_changed': 'threshold=0.30',
        'metric_optimized': 'recall',
        'validation_score': None,
        'test_score': None,
        'notes': 'record false-positive tradeoff',
    },
]

tuning_log_df = pd.DataFrame(tuning_runs)
tuning_log_df

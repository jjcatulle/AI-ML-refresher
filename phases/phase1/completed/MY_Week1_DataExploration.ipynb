# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %% [markdown]
# # PHASE 1, WEEK 1: Data Exploration Challenge 🔍
#
# ## Your Mission
# Learn to load, explore, and analyze data using NumPy, Pandas, and Matplotlib.
#
# ## What You'll Build
# An exploratory data analysis (EDA) on a real dataset with visualizations and insights.
#
# ---

# %% [markdown]
# ## Challenge 1: Import Libraries ✅
#
# **TODO**: Import these libraries
# - `numpy` as `np`
# - `pandas` as `pd`
# - `matplotlib.pyplot` as `plt`
# - `seaborn` as `sns`
#
# **Hint**: Use `import X as Y` syntax

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before continuing into visualization and model-oriented analysis.
#
# Use Phase 0 as your reference:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 1 sections)
#
# Questions to answer in markdown before moving on:
# 1. What data quality issues exist (missing values, wrong types, duplicates, outliers)?
# 2. What transformations are required before deeper analysis or training?
# 3. Is the target definition clear and consistent (if target exists)?
# 4. What baseline result or benchmark will you compare against?
#
# Done criteria:
# - You can explain your preparation plan in plain language.
# - You can justify preprocessing decisions before moving forward.
# - You are ready to proceed with a clean strategy.

# %% [markdown]
# ## Challenge 2: Load Data
#
# **TODO**: Load the Iris dataset using scikit-learn
#
# ```python
# from sklearn.datasets import load_iris
# ```
#
# Then:
# 1. Load iris data
# 2. Create a DataFrame with columns from `iris.feature_names`
# 3. Add a 'species' column using `iris.target_names[iris.target]`
#
# **Expected output**: DataFrame with 150 rows, 5 columns (4 features + species)

# %%
from sklearn.datasets import load_iris

iris=load_iris()

iris_df=pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df['species']=iris.target_names[iris.target]
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %% [markdown]
# ## Challenge 3: Explore Structure
#
# **TODO**: Answer these questions about your dataset
#
# 1. What are the dimensions? (Use `.shape`)
# 2. What are the column names? (Use `.columns`)
# 3. What are the data types? (Use `.dtypes`)
# 4. Show first 3 rows (Use `.head()`)
# 5. Show info about the dataset (Use `.info()`)

# %%
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
iris_df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# species               object
# dtype: object

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Challenge 4: Summary Statistics
#
# **TODO**: Get statistical summary
#
# 1. Show summary statistics (Use `.describe()`)
# 2. Show mean of each numeric column (Use `.mean()`)
# 3. Show median of each numeric column (Use `.median()`)
# 4. Show count of each species (Use `.value_counts()`)

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
iris_df_copy=iris_df.copy()
iris_df_copy.drop(columns=['species'], inplace=True)
iris_df_copy.mean()
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %%
iris_df_copy.median()
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %%
iris_df.value_counts()
# Out:
# sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  species
# 5.8                2.7               5.1                1.9               virginica     2
# 6.2                2.2               4.5                1.5               versicolor    1
#                    2.9               4.3                1.3               versicolor    1
#                    3.4               5.4                2.3               virginica     1
# 6.3                2.3               4.4                1.3               versicolor    1
#                                                                                        ..
# 5.4                3.9               1.3                0.4               setosa        1
#                                      1.7                0.4               setosa        1
# 5.5                2.3               4.0                1.3               versicolor    1
# ...

# %% [markdown]
# ## Challenge 5: Missing Values
#
# **TODO**: Check for missing data
#
# 1. Count missing values per column (Use `.isnull().sum()`)
# 2. Print total missing value count
# 3. Print percentage of missing data
#
# **Expected**: Iris dataset has NO missing values (clean data!)

# %%
iris_df.isnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
#      species
# 0      False
# ...

# %%
iris_df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
missing_percentage=iris_df.isnull().sum()/len(iris_df)*100
missing_percentage
# Out:
# sepal length (cm)    0.0
# sepal width (cm)     0.0
# petal length (cm)    0.0
# petal width (cm)     0.0
# species              0.0
# dtype: float64

# %% [markdown]
# ## Challenge 6: Filtering Data
#
# **TODO**: Extract insights by filtering
#
# 1. Filter for only setosa species and print count
# 2. Filter for sepal_length > 6.5 and print how many
# 3. Find the flower with max petal_length (Use `.idxmax()`)
# 4. Find the flower with min sepal_width
#
# **Hint**: Use `df[df['column'] > value]` for filtering

# %%
len(iris_df[iris_df["species"]=="setosa"])
# Out:
# 50

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
len(iris_df[iris_df["sepal length (cm)"] > 6.5])
# Out:
# 30

# %%
# .loc is used to access a group of rows and columns by labels or a boolean array
# idxmax() returns the index of the first occurrence of the maximum value in the specified column.
iris_df.loc[iris_df['petal length (cm)'].idxmax()]
# Out:
# sepal length (cm)          7.7
# sepal width (cm)           2.6
# petal length (cm)          6.9
# petal width (cm)           2.3
# species              virginica
# Name: 118, dtype: object

# %%
iris_df.loc[iris_df['petal length (cm)'].idxmin()] #.loc is used to access a group of rows and columns by labels or a boolean array. idxmin() returns the index of the first occurrence of the minimum value in the specified column.
# Out:
# sepal length (cm)       4.6
# sepal width (cm)        3.6
# petal length (cm)       1.0
# petal width (cm)        0.2
# species              setosa
# Name: 22, dtype: object

# %% [markdown]
# ## Challenge 7: Grouping & Aggregation
#
# **TODO**: Group data by species and calculate
#
# 1. Mean of each feature by species (Use `.groupby().mean()`)
# 2. Max sepal_length by species
# 3. Min petal_width by species
# 4. Count of flowers per species
#
# **Expected**: 3 species = Setosa, Versicolor, Virginica

# %%
iris_df.groupby('species').mean()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
iris_df.groupby('species').agg({
    'sepal length (cm)':'max',
    'sepal width (cm)':'min',
})
# Out:
#             sepal length (cm)  sepal width (cm)
# species
# setosa                    5.8               2.3
# versicolor                7.0               2.0
# virginica                 7.9               2.2

# %% [markdown]
# ## Challenge 8: Correlation Analysis
#
# **TODO**: Understand feature relationships
#
# 1. Calculate correlation matrix for numeric columns
#    - Hint: Use `.select_dtypes(include=[np.number])` then `.corr()`
# 2. Find which two features are most correlated
# 3. Create a heatmap visualization
#    - Hint: `sns.heatmap(correlation, annot=True, fmt='.2f', cmap='coolwarm')`

# %%
corr_matrix=iris_df.select_dtypes(include=np.number).corr()
corr_matrix
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
current_max=[];
for column in corr_matrix:
    for index in corr_matrix.index:
        if column!=index:
            if current_max == []:
                current_max = [corr_matrix.loc[index,column], index, column]
            elif abs(corr_matrix.loc[index,column]) > abs(current_max[0]):
                current_max = [corr_matrix.loc[index,column], index, column]
print(f"The highest correlation is between {current_max[1]} and {current_max[2]} with a correlation of {current_max[0]}")
# Out:
# The highest correlation is between petal width (cm) and petal length (cm) with a correlation of 0.9628654314027961

# %%
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Challenge 9: Create Visualizations
#
# **TODO**: Create 3 different plots
#
# ### Plot 1: Histogram
# - Show distribution of sepal_length
# - Add labels and title
# - Use `plt.hist()`
#
# ### Plot 2: Scatter Plot
# - X-axis: sepal_length
# - Y-axis: petal_length
# - Color by species (different colors for each)
# - Use `plt.scatter()` with a loop or `sns.scatterplot()`
#
# ### Plot 3: Box Plot
# - Show sepal_length distribution by species
# - Use `sns.boxplot()` or `df.boxplot()`

# %%
plt.hist(iris_df['sepal length (cm)'], bins=20, edgecolor='black')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()

# %%
color_map={};
for species in iris_df['species'].unique():
    color_map[species]=np.random.rand(3,)
colors=iris_df['species'].map(color_map)

plt.scatter(iris_df['sepal length (cm)'], iris_df['sepal width (cm)'], c=colors)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Sepal Width')

plt.show()

# %%
# Plot 3: Box Plot
# YOUR CODE HERE
sns.boxplot(x='species', y='sepal length (cm)', data=iris_df)
plt.title('Box Plot of Sepal Length by Species')
plt.show()

# %% [markdown]
# ## Challenge 10: Write Your Insights
#
# **TODO**: Based on your analysis, answer these questions:
#
# 1. Which species tends to have the largest petals?
# 2. Are sepal_length and petal_length correlated? Explain.
# 3. What's the most interesting pattern you found?
#
# Write your answers as comments or markdown:

# %% [markdown]
# **Your Insights:**
#
# 1.  Virginica tends to be larger
# 2.  yes the .....
# 3.  by nowing the sepal and petal length the species can be dtermined

# %% [markdown]
# ---
#
# ## 🎓 What You Learned
#
# ✅ Load data with Pandas
# ✅ Explore structure and statistics
# ✅ Check for missing values
# ✅ Filter and group data
# ✅ Analyze correlations
# ✅ Create visualizations
# ✅ Draw insights from data
#
# ## 🚀 Next Challenge
# Download a REAL dataset from Kaggle and repeat all 10 challenges!

# %% [markdown]
# ### Import the housing data

# %%
from sklearn.datasets import fetch_california_housing
housing_df = fetch_california_housing(as_frame=True).frame

# %% [markdown]
# ### Explore Data

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
housing_df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# 20635    -121.09        0.781
# 20636    -121.21        0.771
# 20637    -121.22        0.923
# 20638    -121.32        0.847
# 20639    -121.24        0.894

# %%
housing_df.shape
# Out:
# (20640, 9)

# %%
housing_df.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# ### Handle Missing data

# %%
housing_df.isnull()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0       False     False     False      False       False     False     False
# 1       False     False     False      False       False     False     False
# 2       False     False     False      False       False     False     False
# 3       False     False     False      False       False     False     False
# 4       False     False     False      False       False     False     False
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635   False     False     False      False       False     False     False
# 20636   False     False     False      False       False     False     False
# 20637   False     False     False      False       False     False     False
# 20638   False     False     False      False       False     False     False
# 20639   False     False     False      False       False     False     False
#
#        Longitude  MedHouseVal
# ...

# %%
housing_df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# ### Filter and Explore the data

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
housing_df[housing_df['HouseAge']<30]
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 50     0.9218      21.0  2.045662   1.034247       735.0  1.678082     37.82
# 59     2.5625       2.0  2.771930   0.754386        94.0  1.649123     37.82
# 70     1.7719      26.0  6.047244   1.196850       392.0  3.086614     37.81
# 74     2.4830      20.0  6.278195   1.210526       290.0  2.180451     37.81
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
housing_df[(housing_df["Population"]<100) & (housing_df["AveBedrms"]<2)]
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 59     2.5625       2.0  2.771930   0.754386        94.0  1.649123     37.82
# 61     6.1183      49.0  5.869565   1.260870        86.0  3.739130     37.82
# 73     0.4999      46.0  1.714286   0.571429        18.0  2.571429     37.81
# 121    4.9643      37.0  7.106383   1.148936        98.0  2.085106     37.85
# 700    6.5000      20.0  6.451613   0.806452        83.0  2.677419     37.69
# ...       ...       ...       ...        ...         ...       ...       ...
# 20248  8.0000      28.0  2.888889   0.333333        29.0  3.222222     34.25
# 20349  7.3004      32.0  5.724138   0.758621        63.0  2.172414     34.17
# 20353  5.0066      12.0  3.800000   1.466667        69.0  4.600000     34.13
# 20502  2.9821      45.0  4.481481   0.925926        67.0  2.481481     34.33
# 20625  4.1250      37.0  7.285714   1.214286        29.0  2.071429     39.12
#
#        Longitude  MedHouseVal
# ...

# %%
max_house_age_idx = housing_df['HouseAge'].idxmax()
max_house_age = housing_df.loc[max_house_age_idx]
max_house_age
# Out:
# MedInc           7.257400
# HouseAge        52.000000
# AveRooms         8.288136
# AveBedrms        1.073446
# Population     496.000000
# AveOccup         2.802260
# Latitude        37.850000
# Longitude     -122.240000
# MedHouseVal      3.521000
# Name: 2, dtype: float64

# %% [markdown]
# ### Grouping and Aggregation

# %%
housing_df.groupby("HouseAge").agg({
    "AveRooms":"mean",
    "AveBedrms":"mean"
})
# Out:
#           AveRooms  AveBedrms
# HouseAge
# 1.0       9.088091   1.552106
# 2.0       7.649087   1.273514
# 3.0       6.851805   1.192486
# 4.0       6.112610   1.116190
# 5.0       5.963211   1.128014
# 6.0       5.832246   1.105839
# 7.0       6.236576   1.145118
# 8.0       6.280481   1.175100
# 9.0       6.014117   1.144547
# 10.0      6.047608   1.195510
# 11.0      6.288396   1.245155
# 12.0      5.766874   1.122970
# 13.0      6.225630   1.199163
# 14.0      6.101843   1.175591
# 15.0      5.942703   1.142600
# 16.0      6.004060   1.131531
# 17.0      5.879533   1.168132
# 18.0      5.708517   1.124104
# 19.0      5.632239   1.138902
# 20.0      5.466440   1.112190
# 21.0      5.536552   1.110378
# 22.0      5.661284   1.130028
# 23.0      5.584120   1.113509
# 24.0      5.404322   1.090811
# 25.0      5.542334   1.102046
# 26.0      5.547365   1.072149
# 27.0      5.345399   1.101355
# 28.0      5.213263   1.086258
# 29.0      5.215443   1.088691
# ...

# %% [markdown]
# ### Correlation Analysis

# %%
housing_df_numeric = housing_df.select_dtypes(include=np.number)
housing_corr_matrix = housing_df_numeric.corr()
housing_corr_matrix
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
housing_df["Population"].corr(housing_df["AveBedrms"])
# Out:
# np.float64(-0.06619740232676055)

# %%
max_corr=[]

for column in housing_corr_matrix.columns:
    for index in housing_corr_matrix.index:
        if column==index:
            continue
        elif max_corr == []:
            max_corr=[corr_matrix.loc[index,column], index, column]
        elif abs(corr_matrix.loc[index,column]) > abs(max_corr[0]):
            max_corr=[corr_matrix.loc[index,column], index, column]
print(f"The highest correlation is between {max_corr[1]} and {max_corr[2]} with a correlation of {max_corr[0]}")
# Out:
# The highest correlation is between Longitude and Latitude with a correlation of -0.9246644339150362

# %%
sns.heatmap(housing_corr_matrix,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Visualization

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
plt.hist(housing_df['HouseAge'], bins=20, edgecolor='black')
plt.xlabel('House Age')
plt.ylabel('Frequency')
plt.title('Distribution of House Age')
plt.show()

# %%
plt.scatter(housing_df['AveRooms'], housing_df['AveBedrms'], c='blue', alpha=0.5)
plt.xlabel('Average Rooms')
plt.ylabel('Average Bedrooms')
plt.title('Average Rooms vs Average Bedrooms')
plt.show()

# %%
housing_df.boxplot(column='AveRooms', by='MedInc')
# Out:
# <Axes: title={'center': 'AveRooms'}, xlabel='MedInc'>

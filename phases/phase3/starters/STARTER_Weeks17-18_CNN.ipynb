# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %%
# First run check (beginner safe)
import sys
import torch

print('Python version:', sys.version.split()[0])
print('PyTorch version:', torch.__version__)
print('Torch import successful. You can continue.')

# %% [markdown]
# # Beginner Start Here (Weeks 17-18: CNN + Attention)
#
# This notebook introduces deep learning concepts from scratch.
#
# ## What is a neural network?
# A model made of layers that transforms inputs to predictions.
#
# ## Modules used in this notebook
# - `torch`: deep learning framework (tensors, models, training).
# - `torchvision`: image datasets and prebuilt models.
# - `matplotlib`: visualize training and predictions.
#
# ## Key terms
# - Tensor: multi-dimensional array used by PyTorch.
# - Epoch: one full pass through training data.
# - Loss: error value the model tries to minimize.
# - Backpropagation: process to compute gradient updates.
# - Attention: mechanism to focus on important tokens/positions.
# - KV cache: memory optimization for transformer inference.
#
# ## How to work through this notebook
# 1. Get one simple model training first.
# 2. Verify tensor shapes at every step.
# 3. Compare baseline vs improved model.
# 4. Explain results and tradeoffs after each experiment.

# %% [markdown]
# # Weeks 17-18: Convolutional Neural Networks (CNN)
#
# ## Overview
# Build deep learning models for image classification using CNNs.
#
# **Learning Goals:**
# - Neural network fundamentals
# - Convolutional layers and pooling
# - Image preprocessing
# - Training neural networks
# - GPU acceleration
# - Transfer learning
#
# **Time:** 12-16 hours across 2 weeks
#
# **Difficulty:** 🔴 Advanced deep learning concepts
#
# ---
#
# ## Challenge Summary
# 12 challenges to build a CNN from scratch and fine-tune pre-trained models.

# %% [markdown]
# ## Challenge 1: Setup Deep Learning Environment
#
# **Goal:** Configure PyTorch/TensorFlow and GPU.
#
# **Steps:**
# 1. Install PyTorch or TensorFlow
# 2. Check GPU availability
# 3. Import libraries
# 4. Load sample dataset (CIFAR-10, MNIST, or custom)
# 5. Verify device (CPU/GPU)
#
# **Expected:**
# - No import errors
# - GPU available (if CUDA installed)
# - Dataset loaded successfully

# %%
# Challenge 1: Setup Deep Learning Environment

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 2: Explore Image Dataset
#
# **Goal:** Understand image data structure.
#
# **Steps:**
# 1. Load training and test datasets
# 2. Display dataset shapes
# 3. Visualize 9 sample images
# 4. Show class distribution
# 5. Check image dimensions and pixel ranges
#
# **Expected:**
# - Images: height × width × channels (e.g., 32×32×3)
# - Pixel values: 0-255 or 0.0-1.0
# - Multiple classes (10+ for CIFAR-10)

# %%
# Challenge 2: Explore Image Dataset

# YOUR CODE HERE

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before visual analysis and CNN training.
#
# Use Phase 0 as your reference:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 3 sections)
#
# Questions to answer in markdown before moving on:
# 1. What data consistency issues exist (labels, missing files, corrupt samples)?
# 2. What preprocessing and normalization are required before training?
# 3. How will you verify split integrity and avoid leakage?
# 4. What baseline will you compare against first?
#
# Done criteria:
# - You can explain data prep and validation before CNN training.
# - You have a baseline and evaluation plan.
# - You are ready to train with controlled assumptions.

# %% [markdown]
# ## Challenge 3: Preprocess Images
#
# **Goal:** Prepare images for neural network.
#
# **Steps:**
# 1. Normalize pixel values (0-1 or standardize)
# 2. Create data augmentation:
#    - Random rotations
#    - Random crops
#    - Flips
# 3. Create dataloaders (batches of 32-64)
# 4. Verify batch shapes
#
# **Expected:**
# - Normalized pixel values
# - Augmentation applied
# - Batches ready for training

# %%
# Challenge 3: Preprocess Images

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 4: Build Custom CNN
#
# **Goal:** Create neural network from scratch.
#
# **Steps:**
# 1. Design CNN architecture with:
#    - 3-4 convolutional layers
#    - MaxPooling after each conv
#    - Batch normalization
#    - Dropout for regularization
#    - Fully connected layers at end
# 2. Total parameters: 100K - 1M
# 3. Use ReLU activation
# 4. Output layer: softmax (number of classes)
#
# **Example architecture:**
# ```
# Conv(3,32) → ReLU → MaxPool → Conv(32,64) → ReLU → MaxPool →
# FC(1024) → ReLU → Dropout → FC(num_classes)
# ```
#
# **Expected:**
# - Model builds without errors
# - Can pass sample batch through
# - Output shape matches classes

# %%
# Challenge 4: Build Custom CNN

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 5: Setup Training Loop
#
# **Goal:** Implement training infrastructure.
#
# **Steps:**
# 1. Define loss function (CrossEntropyLoss)
# 2. Define optimizer (Adam or SGD)
# 3. Create training function
# 4. Create validation function
# 5. Move model to device (GPU if available)
#
# **Training function should:**
# - Loop through batches
# - Forward pass
# - Calculate loss
# - Backward pass
# - Update weights
#
# **Expected:**
# - Functions ready for training
# - Loss decreases with iterations
# - No memory errors

# %%
# Challenge 5: Setup Training Loop

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 6: Train Custom CNN
#
# **Goal:** Train model for 10-20 epochs.
#
# **Steps:**
# 1. Train for 10+ epochs
# 2. Track metrics:
#    - Training loss
#    - Validation accuracy
#    - Validation loss
# 3. Plot learning curves
# 4. Save best model
# 5. Stop early if validation plateaus
#
# **Expected:**
# - Training loss decreases
# - Validation accuracy improves
# - Accuracy reach 60-80%+ on test set

# %%
# Challenge 6: Train Custom CNN

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 7: Evaluate Custom CNN
#
# **Goal:** Measure model performance.
#
# **Steps:**
# 1. Evaluate on test set
# 2. Calculate accuracy, precision, recall, F1
# 3. Create confusion matrix
# 4. Visualize misclassified examples
# 5. Analyze errors:
#    - Which classes are confused?
#    - Any patterns?
#
# **Expected:**
# - Test accuracy: 65-85%
# - Some classes harder than others
# - Clear error patterns

# %%
# Challenge 7: Evaluate Custom CNN

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 8: Load Pre-trained Model
#
# **Goal:** Use transfer learning for better performance.
#
# **Steps:**
# 1. Load pre-trained model (ResNet18, VGG16, or similar)
# 2. Remove classification head
# 3. Freeze early layers (feature extraction)
# 4. Add new classification head (# classes)
# 5. Verify model structure
#
# **Expected:**
# - Model loads successfully
# - Pre-trained weights loaded
# - Ready for fine-tuning

# %%
# Challenge 8: Load Pre-trained Model

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 9: Fine-tune Pre-trained Model
#
# **Goal:** Adapt pre-trained model to your task.
#
# **Steps:**
# 1. Train new classification head first
# 2. Then unfreeze last few layers
# 3. Use lower learning rate for unfrozen layers
# 4. Train for 5-10 epochs
# 5. Monitor for overfitting
#
# **Expected:**
# - Fast training (pre-trained features)
# - Higher accuracy than custom CNN
# - No overfitting

# %%
# Challenge 9: Fine-tune Pre-trained Model

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 10: Compare Models
#
# **Goal:** Benchmark custom vs pre-trained.
#
# **Steps:**
# 1. Evaluate both models on test set
# 2. Create comparison table:
#    - Accuracy, precision, recall
#    - Number of parameters
#    - Training time
#    - Inference time
# 3. Create visualizations
# 4. Which model would you deploy?
#
# **Expected insight:**
# - Pre-trained usually much better
# - Trade-off: complex but powerful model

# %%
# Challenge 10: Compare Models

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 11: Visualize Learned Features
#
# **Goal:** Understand what CNN learns.
#
# **Steps:**
# 1. Extract activations from early layers
# 2. Visualize convolutional filters
# 3. Show feature maps for sample images
# 4. Create saliency maps (what pixels matter?)
# 5. Interpret what model learned
#
# **Expected:**
# - Early layers: edges, textures
# - Later layers: complex shapes
# - Saliency maps highlight important regions

# %%
# Challenge 11: Visualize Learned Features

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 12: Production Deployment
#
# **Goal:** Prepare model for real-world use.
#
# **Steps:**
# 1. Create inference script:
#    - Load image
#    - Preprocess
#    - Make prediction
#    - Return class + confidence
#
# 2. Create web API (FastAPI or Flask):
#    - POST endpoint for image upload
#    - Return predictions as JSON
#
# 3. Write README with:
#    - Model architecture
#    - Performance metrics
#    - How to deploy
#    - Limitations
#
# 4. Save model for production
#
# **Example API response:**
# ```json
# {
#   "class": "cat",
#   "confidence": 0.98,
#   "top_3": {
#     "cat": 0.98,
#     "dog": 0.01,
#     "bird": 0.01
#   }
# }
# ```

# %%
# Challenge 12: Production Deployment

# YOUR CODE HERE

# %% [markdown]
# ## Transformer Systems Add-on (New)
#
# This week now includes attention and KV cache basics, not only CNN.
#
# Tasks:
# 1. Implement scaled dot-product attention with NumPy or PyTorch.
# 2. Validate output shape and attention weights.
# 3. Simulate KV cache growth with increasing context length.
# 4. Explain why attention is O(n^2) and how it impacts latency/cost.
#
# Pass criteria:
# - Attention implementation runs with correct tensor shapes.
# - KV cache memory table is produced for multiple context lengths.

# %%
# Attention and KV cache template
import torch
import math

def scaled_dot_product_attention(Q, K, V, mask=None):
    d_k = Q.size(-1)
    scores = (Q @ K.transpose(-2, -1)) / math.sqrt(d_k)
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    weights = torch.softmax(scores, dim=-1)
    return weights @ V, weights

# TODO: create sample tensors Q, K, V and verify output shapes
# TODO: create table of kv cache memory growth by context length

# %% [markdown]
# ## Tuning Learning Checkpoint
#
# ### What tuning means in this project
# In CNN training, tuning means changing learning settings that affect optimization speed, generalization, and overfitting.
#
# ### What you should tune first
# - Start with a pretrained or simple baseline.
# - Tune **learning rate** before tuning many other settings.
# - Then consider batch size, epochs, dropout, augmentation strength, and frozen vs unfrozen layers.
#
# ### What to watch for
# - If training loss falls but validation loss rises, you are likely overfitting.
# - If loss barely moves, the learning rate may be too low or the model may be underpowered.
# - If training is unstable, the learning rate may be too high.
#
# ### Questions to answer in this notebook
# 1. What baseline training setup did I start with?
# 2. Which hyperparameter did I tune first, and why?
# 3. Did validation accuracy improve, or did I only improve training performance?
# 4. What sign of overfitting or underfitting do I see after tuning?
#
# See also: `docs/HYPERPARAMETER_TUNING_GUIDE.md` and `docs/QUICK_REFERENCE.md`.

# %% [markdown]
# ## Tuning Report Template
#
# Use this version for CNN or neural-network training.
#
# ```text
# Tuning target: improve validation performance without overfitting
# Baseline model:
# Baseline validation metric:
#
# Failure mode I was trying to improve:
# - validation plateau
# - overfitting
# - unstable training
#
# Setting(s) tuned:
# - learning rate
# - batch size
# - epochs
# - dropout
# - augmentation
# - frozen vs unfrozen layers
#
# Why I chose these first:
#
# Validation method used:
# Metric optimized:
#
# Best setting found:
# Best validation result:
#
# What improved:
# What got worse:
# Overfitting / underfitting signal now:
#
# Final test result:
# Tradeoff accepted:
# Next tuning step:
# ```

# %%
# Tuning evidence log template
import pandas as pd

tuning_runs = [
    {
        'run_name': 'baseline',
        'setting_changed': 'none',
        'metric_optimized': 'validation_accuracy',
        'validation_score': None,
        'test_score': None,
        'notes': 'starting training setup',
    },
    {
        'run_name': 'trial_1',
        'setting_changed': 'learning_rate=0.0005',
        'metric_optimized': 'validation_accuracy',
        'validation_score': None,
        'test_score': None,
        'notes': 'record overfitting or stability changes',
    },
]

tuning_log_df = pd.DataFrame(tuning_runs)
tuning_log_df

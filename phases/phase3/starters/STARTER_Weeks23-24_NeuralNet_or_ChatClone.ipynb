# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %%
# First run check
import sys
import numpy as np
print('Python version:', sys.version.split()[0])
print('NumPy version:', np.__version__)
print('Ready for project setup.')

# %% [markdown]
# # Weeks 23-24 (Optional): Neural Net from Scratch or Mini ChatGPT Clone
#
# ## Pick One Track
# - Track A: NumPy MLP from scratch
# - Track B: Tiny decoder-only language model (ChatGPT-style prototype)
#
# You can do both if time permits, but complete one end-to-end first.

# %% [markdown]
# ## Global Config

# %%
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
TRACK = 'A'  # change to 'B' for ChatClone

# %% [markdown]
# ## Challenge 1: Pick Track and Define Objective
#
# Tasks:
# - Set TRACK to A or B.
# - Write a one-paragraph project objective.
# - Define success metric(s).

# %%
# Challenge 1: YOUR CODE HERE

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before architecture experiments and model training.
#
# Use Phase 0 as your reference for data and workflow discipline:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 3 sections)
#
# Questions to answer in markdown before moving on:
# 1. What input/label quality issues could hurt training?
# 2. What preprocessing and formatting decisions are required first?
# 3. What baseline behavior will you compare against?
# 4. Which failure modes will you track early?
#
# Done criteria:
# - You can explain preparation choices before modeling.
# - You have a baseline and evaluation intent.
# - You are ready for disciplined iteration.

# %% [markdown]
# ## Challenge 2: Data/Token Pipeline Setup
#
# Track A:
# - Load digits/MNIST-like dataset and normalize features.
#
# Track B:
# - Load text corpus and build tokenizer/vocabulary.
# - Prepare context windows and next-token targets.

# %%
# Challenge 2: YOUR CODE HERE

# %% [markdown]
# ## Challenge 3: Build Core Model Architecture
#
# Track A: define MLP layers manually.
# Track B: define tiny decoder block(s) and output head.

# %%
# Challenge 3: YOUR CODE HERE

# %% [markdown]
# ## Challenge 4: Loss and Optimization Step
#
# Track A: implement forward + loss + manual gradient step.
# Track B: implement next-token loss and optimizer step.

# %%
# Challenge 4: YOUR CODE HERE

# %% [markdown]
# ## Challenge 5: Baseline Training Loop
#
# Goal: Train a baseline and log loss each epoch.

# %%
# Challenge 5: YOUR CODE HERE

# %% [markdown]
# ## Challenge 6: Validation and Overfitting Checks
#
# Goal: Add validation metrics and detect overfitting behavior.

# %%
# Challenge 6: YOUR CODE HERE

# %% [markdown]
# ## Challenge 7: Improve Architecture
#
# Goal: Adjust depth/width/heads and compare to baseline.

# %%
# Challenge 7: YOUR CODE HERE

# %% [markdown]
# ## Challenge 8: Stabilization Techniques
#
# Goal: Add one stabilization method (dropout, grad clip, lr schedule).

# %%
# Challenge 8: YOUR CODE HERE

# %% [markdown]
# ## Challenge 9: Inference Function
#
# Track A: predict class probabilities.
# Track B: generate text with temperature/top-k.

# %%
# Challenge 9: YOUR CODE HERE

# %% [markdown]
# ## Challenge 10: Baseline vs Improved Comparison
#
# Goal: Build a small comparison table with metrics and notes.

# %%
# Challenge 10: YOUR CODE HERE

# %% [markdown]
# ## Challenge 11: Error Analysis
#
# Goal: Collect failure examples and categorize likely causes.

# %%
# Challenge 11: YOUR CODE HERE

# %% [markdown]
# ## Challenge 12: Technical Write-up
#
# Write a concise report including:
# - architecture decisions
# - training dynamics
# - what worked and what failed
# - next iteration plan

# %%
# Challenge 12: YOUR CODE HERE

# %% [markdown]
# ## Reflection
#
# 1. What part of the training loop taught you the most?
# 2. Which change gave the largest quality gain?
# 3. What one bug gave you the clearest understanding of model internals?

# %% [markdown]
# ## Checklist
#
# - [ ] Selected one track and defined metrics
# - [ ] Implemented end-to-end training loop
# - [ ] Logged train and validation metrics
# - [ ] Built inference demo
# - [ ] Compared baseline vs improved variant
# - [ ] Completed error analysis and write-up

# %% [markdown]
# ## Tuning Learning Checkpoint
#
# ### What tuning means in this project
# This project can involve either neural-network training or chat system behavior. In both cases, tuning means changing a small number of settings on purpose, then measuring whether the system improved for the right reason.
#
# ### If you are doing the neural-network path
# - Tune learning rate first.
# - Then check batch size, hidden size, dropout, and epochs.
# - Watch validation behavior, not only training loss.
#
# ### If you are doing the chat-system path
# - Tune prompt structure, context length, temperature, retries, and guardrails one at a time.
# - Evaluate answer quality, consistency, and failure behavior.
#
# ### Questions to answer in this notebook
# 1. What baseline system did I start with?
# 2. Which setting did I tune first, and why?
# 3. What metric or behavior improved?
# 4. What got worse when the tuned result got better?
#
# See also: `docs/HYPERPARAMETER_TUNING_GUIDE.md` and `docs/EVALUATION_FRAMEWORK.md`.

# %% [markdown]
# ## Tuning Report Template
#
# Use this version for the neural-net or chat-system path.
#
# ```text
# Tuning target:
# Baseline system/model:
# Baseline quality metric(s):
#
# Path used:
# - neural network
# - chat system
#
# Failure mode I was trying to improve:
# - unstable training
# - weak validation quality
# - inconsistent answers
# - too much latency or cost
#
# Setting(s) tuned:
# - learning rate / batch size / dropout / epochs
# - prompt structure / temperature / context window / retries
#
# Why I chose these first:
#
# Validation method used:
# Metric optimized:
#
# Best setting found:
# Best validation result:
#
# What improved:
# What got worse:
# Remaining weakness:
#
# Final test result:
# Tradeoff accepted:
# Next tuning step:
# ```

# %%
# Tuning evidence log template
import pandas as pd

tuning_runs = [
    {
        'run_name': 'baseline',
        'setting_changed': 'none',
        'metric_optimized': 'primary_quality_metric',
        'validation_score': None,
        'test_score': None,
        'notes': 'record whether you used neural-net or chat path',
    },
    {
        'run_name': 'trial_1',
        'setting_changed': 'learning_rate=... or temperature=...',
        'metric_optimized': 'primary_quality_metric',
        'validation_score': None,
        'test_score': None,
        'notes': 'track quality vs cost or stability',
    },
]

tuning_log_df = pd.DataFrame(tuning_runs)
tuning_log_df

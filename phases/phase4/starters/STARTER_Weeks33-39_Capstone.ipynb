# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %%
# First run check (beginner safe)
import sys

print('Python version:', sys.version.split()[0])
print('Environment check passed.')
print('Build small, test often, then scale to full capstone flow.')

# %% [markdown]
# # Beginner Start Here (Weeks 33-39: Capstone)
#
# This capstone is big, so we break it into clear parts.
#
# ## Final objective
# Build a production-grade autonomous AI system with:
# - multiple collaborating agents,
# - retrieval from multiple sources,
# - evaluation pipeline,
# - safety guardrails.
#
# ## Key terms
# - Architecture: how components connect and exchange data.
# - Pipeline: ordered set of processing steps.
# - Evals: repeatable tests measuring quality and safety.
# - Governance: policies for privacy, fairness, and harmful output prevention.
# - Reliability: system behaves correctly under failures/edge cases.
#
# ## How to work through this notebook
# 1. Build smallest end-to-end version first.
# 2. Add critic and fact-checking.
# 3. Add guardrails and eval suite.
# 4. Improve quality with measurable metrics, not guesses.

# %% [markdown]
# # Weeks 33-39: Capstone Project - End-to-End ML System
#
# ## Overview
# Build a complete ML system from problem definition to production deployment.
#
# **Learning Goals:**
# - Problem formulation
# - Data pipeline
# - Model development
# - Experimentation and iteration
# - API deployment
# - Documentation
# - Real-world constraints
#
# **Time:** 40-50 hours over 7 weeks
#
# **Difficulty:** 🔴🔴 Complete professional project
#
# ---
#
# ## Challenge Summary
# 12 cumulative challenges building a production-ready ML product.

# %% [markdown]
# ## Challenge 1: Problem Definition
#
# **Goal:** Clearly articulate the problem you're solving.
#
# **Steps:**
# 1. Choose a real-world problem:
#    - Recommendation system (e-commerce, movies, music)
#    - Fraud detection (finance, e-commerce)
#    - Demand forecasting (inventory, traffic)
#    - Customer acquisition/retention
#    - Any industry-relevant problem
#
# 2. Write problem statement (1 page):
#    - What's the business problem?
#    - Who are the stakeholders?
#    - What's the impact of solving it?
#    - Current approach (if any)?
#
# 3. Define success metrics:
#    - How will we measure success?
#    - Business metrics (revenue, retention, etc.)
#    - ML metrics (accuracy, precision, AUC, etc.)
#
# 4. Identify constraints:
#    - Data availability?
#    - Latency requirements?
#    - Cost constraints?
#    - Regulatory requirements?
#
# **Expected:**
# - Clear, well-defined problem
# - Measurable objectives
# - Realistic constraints

# %%
# Challenge 1: Problem Definition

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 2: Data Collection and Exploration
#
# **Goal:** Understand your dataset thoroughly.
#
# **Steps:**
# 1. Obtain dataset (Kaggle, public sources, or synthetic)
# 2. Comprehensive exploration:
#    - Shape, types, missing values
#    - Statistical summary
#    - Class distribution (if classification)
#    - Feature correlations
# 3. Visualize distributions
# 4. Identify data quality issues
# 5. Write exploratory report (3-5 pages)
#
# **Report should include:**
# - Overview: size, features, target
# - Data quality: missing data, outliers, duplicates
# - Feature analysis: distributions, correlations, importance
# - Visualizations: 8-10 charts
# - Recommendations: data cleaning approach
#
# **Expected:**
# - Deep understanding of data
# - Identified issues
# - Actionable insights

# %%
# Challenge 2: Data Collection and Exploration

# YOUR CODE HERE

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before capstone modeling and evaluation loops.
#
# Use Phase 0 as your reference for core preparation habits:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 4 sections)
#
# Questions to answer in markdown before moving on:
# 1. What data and pipeline quality issues must be fixed first?
# 2. What transformations are mandatory before training/evaluation?
# 3. What baseline will anchor capstone improvements?
# 4. What failure slices and risks will you track continuously?
#
# Done criteria:
# - You can explain preparation and baseline choices clearly.
# - You have a risk and evaluation tracking plan.
# - You are ready to proceed with full-cycle execution.

# %% [markdown]
# ## Challenge 3: Data Preprocessing Pipeline
#
# **Goal:** Create production-ready data processing.
#
# **Steps:**
# 1. Handle missing values
# 2. Remove duplicates
# 3. Treat outliers
# 4. Feature encoding (categorical → numerical)
# 5. Feature scaling/normalization
# 6. Feature engineering (create new features)
# 7. Create reusable preprocessing pipeline
#
# **Pipeline considerations:**
# - Fit on training data ONLY
# - Apply to test data identically
# - Save pipeline for production
# - Document all transformations
#
# **Expected:**
# - Clean, ready-to-model data
# - No data leakage
# - Reproducible process

# %%
# Challenge 3: Data Preprocessing Pipeline

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 4: Baseline Model
#
# **Goal:** Establish performance baseline.
#
# **Steps:**
# 1. Try simple model first (Logistic Regression, Decision Tree)
# 2. Train with hyperparameter tuning
# 3. Evaluate on test set
# 4. Document baseline performance
# 5. Analyze errors
#
# **Report baseline results:**
# - Accuracy, precision, recall, F1 (classification)
# - R², RMSE (regression)
# - Confusion matrix
# - Feature importance
# - Analysis: what works? what doesn't?
#
# **Expected:**
# - Baseline established
# - Interpretable results
# - Clear next steps

# %%
# Challenge 4: Baseline Model

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 5: Advanced Model Development
#
# **Goal:** Build sophisticated models.
#
# **Steps:**
# 1. Try 3-4 advanced models:
#    - Random Forest/Gradient Boosting
#    - Neural Networks
#    - Ensemble methods
# 2. Hyperparameter tuning for each
# 3. Cross-validation (5-fold minimum)
# 4. Compare all models
# 5. Select best performer
#
# **Comparison table should include:**
# - All metrics
# - Training time
# - Model complexity
# - Interpretability
# - Parameter count
#
# **Expected:**
# - 2-5% improvement over baseline
# - Consistent performance across folds
# - Clear winner identified

# %%
# Challenge 5: Advanced Model Development

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 6: Model Validation and Testing
#
# **Goal:** Thoroughly test final model.
#
# **Steps:**
# 1. Stratified k-fold cross-validation
# 2. Test on held-out test set
# 3. Error analysis:
#    - When does model fail?
#    - Any biases?
#    - Worst-performing segments?
# 4. Business metric calculation
# 5. ROI analysis
#
# **Test report should cover:**
# - Overall performance metrics
# - Confusion matrix + interpretation
# - Tests by segment (if applicable)
# - False positives/negatives cost analysis
# - Business impact projection
#
# **Expected:**
# - Confident in model performance
# - Identified limitations
# - Ready for production

# %%
# Challenge 6: Model Validation and Testing

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 7: API Development
#
# **Goal:** Deploy model as web service.
#
# **Steps:**
# 1. Create FastAPI application
# 2. Load trained model
# 3. Create prediction endpoints
# 4. Add health checks and monitoring
# 5. Implement error handling
# 6. Add request logging
# 7. Create API documentation
#
# **API should support:**
# - Single predictions
# - Batch predictions
# - Explainability (feature importance)
# - Monitoring endpoints
# - Health checks
#
# **Expected:**
# - Robust, fast API
# - Clear documentation
# - Ready for users

# %%
# Challenge 7: API Development

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 8: Containerization and Deployment
#
# **Goal:** Package for production deployment.
#
# **Steps:**
# 1. Create Dockerfile
# 2. Create docker-compose if needed
# 3. Write deployment scripts
# 4. Test locally
# 5. Deploy to cloud platform
# 6. Setup monitoring and logging
# 7. Create runbooks for operations
#
# **Deployment checklist:**
# - [ ] Dockerfile builds
# - [ ] Container runs locally
# - [ ] API responses correct
# - [ ] Logging enabled
# - [ ] Monitoring setup
# - [ ] Performance acceptable
# - [ ] Scaling working
# - [ ] Backups configured
#
# **Expected:**
# - Production-ready deployment
# - Monitoring in place
# - Automated alerts

# %%
# Challenge 8: Containerization and Deployment

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 9: Monitoring and Maintenance
#
# **Goal:** Keep model performing in production.
#
# **Steps:**
# 1. Setup performance monitoring
# 2. Implement data drift detection
# 3. Model drift monitoring
# 4. Create alerting system
# 5. Write maintenance procedures
# 6. Plan model retraining schedule
#
# **Monitoring metrics:**
# - Prediction latency
# - Error rate
# - API availability
# - Data drift (feature distributions)
# - Model drift (prediction changes)
# - User feedback/ratings
#
# **Retraining strategy:**
# - Frequency: weekly/monthly?
# - Trigger: scheduled or performance-based?
# - A/B testing for new models
# - Rollback plan
#
# **Expected:**
# - Comprehensive monitoring
# - Early issue detection
# - Automated alerts

# %%
# Challenge 9: Monitoring and Maintenance

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 10: Performance Analysis and Optimization
#
# **Goal:** Improve speed and efficiency.
#
# **Steps:**
# 1. Profile API endpoint
# 2. Identify bottlenecks
# 3. Optimize:
#    - Model inference (quantization, pruning)
#    - Caching predictions
#    - Batch processing
#    - Database queries
# 4. Benchmark improvements
# 5. Load test (concurrent users)
# 6. Cost analysis
#
# **Optimization targets:**
# - P99 latency < 100ms (single prediction)
# - Throughput > 100 req/sec
# - Memory < 500MB
# - Cost < budget
#
# **Expected:**
# - 20-50% speedup
# - Proven load capacity
# - Cost reduction

# %%
# Challenge 10: Performance Analysis and Optimization

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 11: Documentation and Knowledge Transfer
#
# **Goal:** Create comprehensive documentation.
#
# **Documentation to create:**
#
# 1. **README.md** (1-2 pages)
#    - Project overview
#    - Quick start guide
#    - Key results
#
# 2. **Architecture.md** (3-5 pages)
#    - System design diagram
#    - Data flow
#    - Model pipeline
#    - Deployment architecture
#
# 3. **Developer Guide** (5-10 pages)
#    - Installation
#    - Local development setup
#    - Testing procedures
#    - Code structure
#    - How to modify/extend
#
# 4. **Operations Guide** (5-10 pages)
#    - Deployment procedures
#    - Monitoring dashboards
#    - Troubleshooting guide
#    - Scaling strategy
#    - Disaster recovery
#
# 5. **Model Card** (2-3 pages)
#    - Model overview
#    - Training data
#    - Performance metrics
#    - Known limitations
#    - Recommendations
#
# 6. **Business Report** (5-10 pages)
#    - Executive summary
#    - Problem & solution
#    - Results & ROI
#    - Next steps
#
# **Expected:**
# - Any team member can understand and operate system
# - Clear handoff possible
# - Future maintainability

# %%
# Challenge 11: Documentation and Knowledge Transfer

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 12: Reflection and Future Work
#
# **Goal:** Synthesize learnings and plan improvements.
#
# **Steps:**
# 1. **Project Retrospective:**
#    - What went well?
#    - What was difficult?
#    - Key learnings?
#    - What would you do differently?
#
# 2. **System Evaluation:**
#    - Does it solve the business problem?
#    - Performance vs. requirements?
#    - User satisfaction?
#    - Cost-benefit analysis?
#
# 3. **Future Improvements (6-12 months out):**
#    - Model improvements
#      - Better features?
#      - Different algorithms?
#      - More data?
#    - System enhancements
#      - Scale to 10x users?
#      - Latency requirements?
#      - New use cases?
#    - Operational improvements
#      - Better monitoring?
#      - Automated retraining?
#      - Team growth?
#
# 4. **Career Development:**
#    - Skills developed?
#    - Gaps identified?
#    - Next learning goals?
#    - Portfolio addition?
#
# **Reflection document (5-10 pages) covering:**
# - Project summary
# - Technical achievements
# - Business impact
# - Lessons learned
# - Improvement roadmap
# - Personal growth
#
# **Expected:**
# - Demonstrated mastery of ML/AI concepts
# - Production system understanding
# - Clear path forward

# %%
# Challenge 12: Reflection and Future Work

# YOUR CODE HERE

# %% [markdown]
# ## Autonomous Agent Capstone Upgrade (New)
#
# Final capstone should be an autonomous, production-grade agent.
#
# Required flow:
# - Planner -> Researcher -> Writer -> Critic.
# - Critic must verify claims against retrieved evidence.
# - Guardrail layer must redact customer names or sensitive fields.
# - Auto-eval script must score factuality and completeness.
#
# Pass criteria:
# - End-to-end run succeeds on at least 5 test inputs.
# - Critic catches at least one injected factual error.
# - Eval report is generated as JSON.

# %%
# Autonomous capstone orchestrator template

def planner(task):
    return {"plan": ["collect_evidence", "draft", "critique"]}

def researcher(inputs):
    # TODO: retrieve from pdf/video/csv sources
    return {"evidence": []}

def writer(evidence):
    # TODO: produce first draft
    return {"draft": ""}

def critic(draft, evidence):
    # TODO: fact-check and return score/issues
    return {"score": 0.0, "issues": []}

def redact_pii(text):
    # TODO: redact names/customer identifiers
    return text

# TODO: wire end-to-end run and emit eval JSON report

# %% [markdown]
# ## Tuning Learning Checkpoint
#
# ### What tuning means in this project
# In the capstone, tuning means making evidence-based improvements across the full system, not just one model. You may tune model settings, thresholds, retrieval parameters, prompts, retries, or serving behavior depending on the architecture you choose.
#
# ### What you should tune first
# - Start with a baseline pipeline and a held-out eval set.
# - Identify the weakest subsystem first.
# - Tune one meaningful group of settings at a time.
#
# ### What to record
# - baseline system
# - metric optimized
# - setting changed
# - validation result
# - cost, latency, or safety tradeoff
# - final test result
#
# ### Questions to answer in this notebook
# 1. What subsystem did I tune first, and why?
# 2. What metric was I optimizing?
# 3. Did the change improve the whole system or only one narrow score?
# 4. What would I tune next if I had one more iteration?
#
# See also: `docs/HYPERPARAMETER_TUNING_GUIDE.md`, `docs/EVALUATION_FRAMEWORK.md`, and `docs/ONE_PAGE_ML_FLOW_CARD.md`.

# %% [markdown]
# ## Tuning Report Template
#
# Use this version for the capstone or any multi-component system.
#
# ```text
# Tuning target: improve full-system behavior
# Baseline system:
# Baseline success / quality / latency / cost / safety:
#
# Weakest subsystem identified first:
#
# Failure mode I was trying to improve:
# - model quality weak
# - retrieval weak
# - orchestration weak
# - latency or cost too high
# - safety behavior weak
#
# Setting(s) tuned:
# - model settings
# - thresholds
# - retrieval settings
# - prompt structure
# - retries / timeouts / caching / batching
#
# Why I chose these first:
#
# Validation method used:
# Metric optimized:
#
# Best setting found:
# Best validation result:
#
# What improved:
# What got worse:
# System-level tradeoff accepted:
#
# Final test result:
# Next tuning step:
# ```

# %%
# Tuning evidence log template
import pandas as pd

tuning_runs = [
    {
        'run_name': 'baseline',
        'setting_changed': 'none',
        'metric_optimized': 'primary_system_metric',
        'validation_score': None,
        'test_score': None,
        'notes': 'starting full-system baseline',
    },
    {
        'run_name': 'trial_1',
        'setting_changed': 'record the first subsystem change',
        'metric_optimized': 'primary_system_metric',
        'validation_score': None,
        'test_score': None,
        'notes': 'track system-wide tradeoffs, not only one score',
    },
]

tuning_log_df = pd.DataFrame(tuning_runs)
tuning_log_df

# %% [markdown]
# # Full Process Lens For This Project
#
# Use this section every time you start a project so you practice the same end-to-end workflow, not just isolated coding tasks.
#
# ## 1) Data Transformation and Processing (What and Why)
#
# Raw data is rarely model-ready. Your first job is to transform data into a reliable, learnable format.
#
# What to do in every project:
# - Identify data types and expected schema.
# - Handle missing values, duplicates, and inconsistent formats.
# - Convert features into model-usable representations (encoding, scaling, tokenization, chunking, etc.).
# - Keep transformations reproducible so train and inference use the same logic.
# - Document assumptions and risks introduced by preprocessing choices.
#
# Why this matters:
# - Better preprocessing usually improves results more than switching algorithms.
# - Poor preprocessing creates hidden errors that look like model failure.
#
# ## 2) Evaluating and Improving Models (What and Why)
#
# Evaluation is not the last step. It is the loop that drives improvement.
#
# What to do in every project:
# - Start with a baseline and compare against it.
# - Choose metrics tied to the real goal (not just convenience metrics).
# - Inspect errors by slice (segments, classes, edge cases).
# - Tune thresholds, features, prompts, retrieval settings, or hyperparameters based on evidence.
# - Re-evaluate after each change and keep track of what improved and what regressed.
#
# Why this matters:
# - A model can appear good overall but fail on important cases.
# - Iterative evaluation is how projects become production-ready, not just demo-ready.
#
# ## 3) Project Reflection Checklist
#
# Before marking this project complete, confirm:
# - I can explain how data was transformed and why.
# - I can explain which metrics I chose and why.
# - I can show at least one improvement cycle from evaluation findings.
# - I can describe current limitations and next improvements.

# %%
# First run check (beginner safe)
import sys

print('Python version:', sys.version.split()[0])
print('Environment check passed.')
print('API coding starts after the concept markdown cells.')

# %% [markdown]
# # Beginner Start Here (Weeks 27-28: FastAPI + Production)
#
# This notebook teaches deployment concepts even if APIs are new to you.
#
# ## What is FastAPI?
# A Python framework to build web APIs quickly.
#
# ## Why APIs for ML?
# Your model becomes usable by apps through HTTP requests.
#
# ## Key terms
# - Endpoint: URL path for one API function (`/predict`, `/health`).
# - Request: data sent to API.
# - Response: data returned by API.
# - Validation: checking input structure and type.
# - Guardrail: safety checks before and after model output.
# - Shadow mode: run a candidate model in background for comparison.
#
# ## How to work through this notebook
# 1. Build minimal API first.
# 2. Add request validation.
# 3. Add guardrails.
# 4. Add shadow mode logging and compare outputs.

# %% [markdown]
# # Weeks 27-28: FastAPI and Model Deployment
#
# ## Overview
# Build production-ready APIs to serve ML models using FastAPI.
#
# **Learning Goals:**
# - FastAPI fundamentals
# - API design best practices
# - Model serving and inference
# - Docker containerization
# - Deployment to cloud
# - Monitoring and logging
#
# **Time:** 14-18 hours across 2 weeks
#
# **Difficulty:** 🔴 Advanced MLOps concepts
#
# ---
#
# ## Challenge Summary
# 12 challenges to build and deploy a complete ML pipeline as API.

# %% [markdown]
# ## Challenge 1: Setup FastAPI Project
#
# **Goal:** Initialize FastAPI development environment.
#
# **Steps:**
# 1. Install FastAPI, Uvicorn, Pydantic
# 2. Create project structure:
#    ```
#    ml-api/
#    ├── main.py          (FastAPI app)
#    ├── models/          (ML models)
#    ├── schemas/         (Request/response models)
#    ├── requirements.txt
#    └── .env
#    ```
# 3. Create hello world endpoint
# 4. Run server: `uvicorn main:app --reload`
# 5. Test at http://localhost:8000/docs
#
# **Expected:**
# - Server starts without errors
# - Swagger docs accessible
# - Hello endpoint works

# %%
# Challenge 1: Setup FastAPI Project

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 2: Define API Schemas
#
# **Goal:** Create request/response models.
#
# **Steps:**
# 1. Use Pydantic for data validation
# 2. Create request schema (input data)
# 3. Create response schema (output format)
# 4. Add field validations and descriptions
# 5. Test schema validation
#
# **Example for ML model:**
# ```python
# class PredictionRequest(BaseModel):
#     feature1: float
#     feature2: float
#
# class PredictionResponse(BaseModel):
#     prediction: float
#     confidence: float
# ```
#
# **Expected:**
# - Schemas defined clearly
# - Type hints present
# - Validation works

# %%
# Challenge 2: Define API Schemas

# YOUR CODE HERE

# %% [markdown]
# ## Pre-Training Learning Checkpoint (Before Visualization or Modeling)
#
# Complete this teaching checkpoint before API evaluation and production comparisons.
#
# Use Phase 0 as your reference for disciplined preparation:
# - guides/phase0/GUIDE_Week2_PandasDeep.md
# - guides/phase0/GUIDE_Week3_NumPyDeep.md
# - guides/phase0/GUIDE_Week4_Visualization.md
# - docs/AI-ML-LEARNING-GUIDE.md (Phase 0 and Phase 4 sections)
#
# Questions to answer in markdown before moving on:
# 1. What data/schema issues can break the API workflow?
# 2. What preprocessing assumptions must be documented before serving?
# 3. What baseline service behavior will you compare against?
# 4. What regression risks must be tracked from the start?
#
# Done criteria:
# - You can explain data and serving assumptions before deployment work.
# - You have baseline expectations and regression criteria.
# - You are ready for controlled production iteration.

# %% [markdown]
# ## Challenge 3: Load Pre-trained Model
#
# **Goal:** Integrate ML model with API.
#
# **Steps:**
# 1. Load pre-trained model (pickle, joblib, or PyTorch)
# 2. Create model wrapper class
# 3. Implement prediction method
# 4. Handle edge cases (invalid input)
# 5. Test model loading and prediction
#
# **Expected:**
# - Model loads on startup
# - Can make predictions
# - Fast inference (< 1 second)

# %%
# Challenge 3: Load Pre-trained Model

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 4: Create Prediction Endpoint
#
# **Goal:** Expose model through REST API.
#
# **Steps:**
# 1. Create POST endpoint: `/predict`
# 2. Accept PredictionRequest
# 3. Call model
# 4. Return PredictionResponse
# 5. Add error handling
#
# **Example:**
# ```python
# @app.post("/predict", response_model=PredictionResponse)
# def predict(request: PredictionRequest):
#     prediction = model.predict(request)
#     return PredictionResponse(prediction=prediction, confidence=0.95)
# ```
#
# **Expected:**
# - Endpoint responds correctly
# - Input validation works
# - Returns JSON response

# %%
# Challenge 4: Create Prediction Endpoint

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 5: Add Health Check and Info Endpoints
#
# **Goal:** Create operational endpoints.
#
# **Steps:**
# 1. Create GET `/health` endpoint
#    - Returns: {"status": "healthy", "uptime": ".."}
# 2. Create GET `/info` endpoint
#    - Returns: model name, version, endpoint list
# 3. Create GET `/metrics` endpoint
#    - Returns: predictions_count, avg_response_time
# 4. Test all endpoints
#
# **Expected:**
# - All endpoints return valid JSON
# - Metrics updated correctly
# - Health check always works

# %%
# Challenge 5: Add Health Check and Info Endpoints

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 6: Implement Logging and Monitoring
#
# **Goal:** Track API usage and errors.
#
# **Steps:**
# 1. Setup logging to files
# 2. Log all predictions (input/output)
# 3. Log API errors and exceptions
# 4. Store metrics (response times, predictions count)
# 5. Create logging middleware
#
# **Log format:**
# ```
# 2024-01-15 10:30:45 | INFO | Prediction received | input: {...} | output: 0.87
# 2024-01-15 10:31:02 | ERROR | Invalid input | error: "feature1 required"
# ```
#
# **Expected:**
# - Logs written to file
# - All predictions logged
# - Errors captured

# %%
# Challenge 6: Implement Logging and Monitoring

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 7: Error Handling and Validation
#
# **Goal:** Make API robust to invalid inputs.
#
# **Steps:**
# 1. Validate input data types
# 2. Check value ranges
# 3. Handle missing fields
# 4. Return meaningful error messages
# 5. Use proper HTTP status codes:
#    - 200: Success
#    - 400: Bad request
#    - 500: Server error
#
# **Test cases:**
# - Missing required field
# - Wrong data type
# - Out of range values
# - Empty request
#
# **Expected:**
# - Graceful error messages
# - Correct status codes
# - No crashes

# %%
# Challenge 7: Error Handling and Validation

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 8: Authentication and Authorization
#
# **Goal:** Secure API endpoints.
#
# **Steps:**
# 1. Implement API key authentication
# 2. Create dependency for key validation
# 3. Require API key for predictions
# 4. Allow public access to health check
# 5. Log authentication attempts
#
# **Usage example:**
# ```
# curl -H "X-API-Key: your-key" http://localhost:8000/predict
# ```
#
# **Expected:**
# - Unauthenticated requests rejected (401)
# - Valid key allows access
# - Different endpoints have different auth

# %%
# Challenge 8: Authentication and Authorization

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 9: Batch Predictions
#
# **Goal:** Handle multiple predictions efficiently.
#
# **Steps:**
# 1. Create `/batch-predict` endpoint
# 2. Accept list of inputs (max 100)
# 3. Return list of predictions
# 4. Optimize for performance
# 5. Test on various batch sizes
#
# **Request format:**
# ```json
# {
#   "requests": [
#     {"feature1": 1.0, "feature2": 2.0},
#     {"feature1": 3.0, "feature2": 4.0}
#   ]
# }
# ```
#
# **Expected:**
# - Batch predictions faster than single calls
# - Returns all results
# - Handles large batches

# %%
# Challenge 9: Batch Predictions

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 10: Create Docker Container
#
# **Goal:** Package API in Docker.
#
# **Steps:**
# 1. Create Dockerfile:
#    ```dockerfile
#    FROM python:3.9
#    WORKDIR /app
#    COPY requirements.txt .
#    RUN pip install -r requirements.txt
#    COPY . .
#    CMD ["uvicorn", "main:app", "--host", "0.0.0.0"]
#    ```
# 2. Create requirements.txt
# 3. Build image: `docker build -t ml-api .`
# 4. Run container: `docker run -p 8000:8000 ml-api`
# 5. Test: curl http://localhost:8000/docs
#
# **Expected:**
# - Image builds successfully
# - Container runs
# - API accessible from host

# %%
# Challenge 10: Create Docker Container

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 11: Performance Testing
#
# **Goal:** Benchmark API performance.
#
# **Steps:**
# 1. Measure response times
# 2. Load test: simultaneous requests
# 3. Test different batch sizes
# 4. Measure memory usage
# 5. Create performance report
#
# **Metrics to track:**
# - Latency (p50, p95, p99)
# - Throughput (requests/second)
# - Memory usage
# - Error rate under load
#
# **Expected:**
# - Response time < 100ms (single)
# - Can handle 100+ requests/sec
# - No memory leaks

# %%
# Challenge 11: Performance Testing

# YOUR CODE HERE

# %% [markdown]
# ## Challenge 12: Cloud Deployment
#
# **Goal:** Deploy API to cloud platform.
#
# **Steps:**
# 1. Choose platform (AWS, GCP, Azure, or Heroku)
# 2. Create deployment guide with:
#    - Prerequisites
#    - Step-by-step instructions
#    - Environment variables
#    - Cost estimation
# 3. Deploy application
# 4. Test from public URL
# 5. Set up monitoring
#
# **Example (AWS Lambda + API Gateway):**
# ```
# 1. Package FastAPI with serverless framework
# 2. Deploy: serverless deploy
# 3. Get endpoint: https://xxx.execute-api.aws.com/predict
# 4. Monitor: CloudWatch logs
# ```
#
# **Write comprehensive README with:**
# - Architecture diagram
# - API documentation
# - Example requests/responses
# - Performance metrics
# - Scaling recommendations
# - Cost breakdown

# %%
# Challenge 12: Cloud Deployment

# YOUR CODE HERE

# %% [markdown]
# ## Guardrails + Shadow Mode Challenge (New)
#
# Upgrade serving from API-only to governance-first production.
#
# Tasks:
# 1. Add input guardrail checks (PII and prompt injection patterns).
# 2. Add output guardrail checks (toxicity and policy violations).
# 3. Implement shadow mode to compare candidate model against current model.
# 4. Log side-by-side quality and latency differences.
#
# Pass criteria:
# - Requests violating policy are blocked or redacted.
# - Shadow mode report includes win/loss/tie summary.

# %%
# Guardrails + shadow mode template
import re

PII_PATTERNS = [
    re.compile(r"\b\d{3}-\d{2}-\d{4}\b"),
    re.compile(r"\b\d{16}\b"),
]

def has_pii(text):
    return any(p.search(text) for p in PII_PATTERNS)

def shadow_compare(current_output, candidate_output):
    # TODO: add judge/eval scoring
    return {
        "current_len": len(current_output),
        "candidate_len": len(candidate_output),
        "same": current_output == candidate_output,
    }

# TODO: run current and candidate model in parallel and log side-by-side results

# %% [markdown]
# ## Tuning Learning Checkpoint
#
# ### What tuning means in this project
# In a serving project, tuning often means balancing model quality with latency, reliability, and production behavior.
#
# ### What you should tune first
# - Keep the model baseline stable.
# - Tune request validation, batching choices, timeout settings, caching, and threshold behavior one at a time.
# - Measure both quality and service performance.
#
# ### What to watch for
# - A better model can still be a worse API if latency or failure rate becomes unacceptable.
# - Faster responses are not enough if the decision quality degrades.
#
# ### Questions to answer in this notebook
# 1. Which production behavior am I trying to improve?
# 2. What setting did I tune first, and why?
# 3. Did the change improve both quality and service behavior?
# 4. What tradeoff remains between speed, cost, and correctness?
#
# See also: `docs/HYPERPARAMETER_TUNING_GUIDE.md` and `docs/EVALUATION_FRAMEWORK.md`.

# %% [markdown]
# ## Tuning Report Template
#
# Use this version for serving and production behavior.
#
# ```text
# Tuning target: improve production behavior
# Baseline system:
# Baseline quality / latency / reliability:
#
# Failure mode I was trying to improve:
# - latency too high
# - request failures too frequent
# - quality good but throughput poor
# - quality drops under production constraints
#
# Setting(s) tuned:
# - timeout
# - caching
# - batching
# - threshold behavior
# - request validation or retry policy
#
# Why I chose these first:
#
# Validation method used:
# Metric optimized:
#
# Best setting found:
# Best validation result:
#
# What improved:
# What got worse:
# Production tradeoff accepted:
#
# Final test result:
# Next tuning step:
# ```

# %%
# Tuning evidence log template
import pandas as pd

tuning_runs = [
    {
        'run_name': 'baseline',
        'setting_changed': 'none',
        'metric_optimized': 'latency_or_quality',
        'validation_score': None,
        'test_score': None,
        'notes': 'starting service behavior',
    },
    {
        'run_name': 'trial_1',
        'setting_changed': 'timeout=15, cache=on',
        'metric_optimized': 'reliability',
        'validation_score': None,
        'test_score': None,
        'notes': 'track service tradeoffs clearly',
    },
]

tuning_log_df = pd.DataFrame(tuning_runs)
tuning_log_df
